# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjx01/GenAI/blob/main/T1_Exploring_Open_Source_LLM's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !pip install -q -U transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 95.7 MB/s eta 0:00:00

# %%
from transformers import pipeline

# %%
generator = pipeline('text-generation', model='gpt2')
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
output = generator("Artificial intelligence is", max_new_tokens = 20)
# Out:
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output)
# Out:
# [{'generated_text': "Artificial intelligence is used to solve a variety of problems. It's a key part of the computer science curriculum, but"}]

# %%
output = generator("Artificial intelligence is", min_new_tokens = 20)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `min_new_tokens` (=20) and `min_length`(=0) seem to have been set. `min_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output)
# Out:
# [{'generated_text': "Artificial intelligence is not some magic wand that could be easily manipulated. It's a sophisticated and well-developed system that will be able to solve complex problems, and it could even become a powerful tool for other kinds of AI.\n\nYou will be able to find and share with your friends and family, and you can share with your friends and family, and you can share with your friends and family, and you can share with your friends and family, and you can share with your friend and family, and you can share with your friend and family, and you can share with your friends and family, and you can share with your friend and family, and you can share with your friend and family, and you can share with your friends and family, and you can share with your friend and family, and you can share with your friend and family, and you can share with your friend and family, and you can share with your friend and family, and you can share with your friend and family, and you c
# ...

# %%
output = generator("The future of AI is", min_new_tokens = 20)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `min_new_tokens` (=20) and `min_length`(=0) seem to have been set. `min_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output)
# Out:
# [{'generated_text': "The future of AI is not in it or in it's future. We are living in a future that is much more like the world we know today.\n\nWe are living in the future that will be much more like the world we know today.\n\nThere is a lot of uncertainty about AI and what it will do for humanity. A lot of people are worried about what AI will do for human beings.\n\nWith the rise of AI, more and more people are worried about what AI will do for human beings.\n\nAI is a disruptive technology that is disruptive to human society.\n\nAI is a disruptive technology that is disruptive to humanity.\n\nIf we don't embrace the technology, we will not be able to solve problems in our own time.\n\nBy embracing AI, we will be able to create a better world that is not just better but better than we have ever imagined.\n\nAI is not just a new technology but a new world.\n\nWe are living in a new world.\n\nAI is not just a new technology but a new world.\n\nIt is a new technology that will cha
# ...

# %%
output = generator("The capital of Karnataka is", max_new_tokens = 20)
# Out:
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output)
# Out:
# [{'generated_text': 'The capital of Karnataka is a city with a population of over 500,000. Most of the residents of the city are farmers'}]

# %%
output = generator("A robot entered the classroom and", max_new_tokens = 20, temperature = 0.2, do_sample = True)
print(output)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'A robot entered the classroom and began to teach the class.\n\nThe robot, which was not named, was a robot that'}]

# %%
output = generator("A robot entered the classroom and", max_new_tokens = 20, temperature = 1.0, do_sample = True)
print(output)
# Out:
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'A robot entered the classroom and called for an emergency medical response. This is not only a good thing, but it should save the'}]

# %%
output = generator("A robot entered the classroom and", max_new_tokens = 20, temperature = 1.2, do_sample = True)
print(output)
# Out:
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "A robot entered the classroom and looked on.\n\nWhile the computer's display had appeared the previous evening, the class showed a"}]

# %%
output = generator("A robot entered the classroom and", max_new_tokens = 20, temperature = 1.2, do_sample = False)
print(output)
# Out:
# [transformers] The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'A robot entered the classroom and began to teach the class.\n\n"I was like, \'Oh my God, this is'}]

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
text = "My name is Arjun, I study at NIE."

# %%
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['My', 'Ġname', 'Ġis', 'ĠAr', 'jun', ',', 'ĠI', 'Ġstudy', 'Ġat', 'ĠN', 'IE', '.']

# %%
token_ids = tokenizer.encode(text)
print(token_ids)
# Out:
# [3666, 1438, 318, 943, 29741, 11, 314, 2050, 379, 399, 10008, 13]
